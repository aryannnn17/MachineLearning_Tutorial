# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
# Read CSV DATA file 
df = pd.read_csv('Data.csv', sep='\t')  
df
# Out:
#    Area   Price
# 0  3000  470000
# 1  3400  530000
# 2  3800  566000
# 3  4000  590000
# 4  4500  640000

# %%
# Plot the data
# %matplotlib inline
plt.xlabel('Area (sqft)')
plt.ylabel('Price (USD)')
plt.scatter(df.Area, df.Price, color='red', marker='x')

# %%
# Train the model using Linear Regression
reg = linear_model.LinearRegression()
reg.fit(df[['Area']], df.Price)
# Out:
# LinearRegression()

# %%
# predict the price for a given area
reg.predict([[4200]])
# Out:
# C:\Users\ARYAN BHAGAT\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([610304.87804878])

# %%
# Plot the regression line
# %matplotlib inline
plt.xlabel('Area (sqft)')
plt.ylabel('Predicted Price (USD)')
plt.scatter(df.Area, df.Price, color='red', marker='x')
plt.plot(df.Area, reg.predict(df[['Area']]), color='blue')

# %%
reg.intercept_
# Out:
# 143695.12195121968

# %%
reg.coef_
# Out:
# array([111.09756098])

# %%
p = pd.read_csv('Area.csv')
p
# Out:
#    Area
# 0  3500
# 1  3600
# 2  3900

# %%
pred = reg.predict(p)

# %%
p['Price'] = pred
p
# Out:
#    Area          Price
# 0  3500  532536.585366
# 1  3600  543646.341463
# 2  3900  576975.609756

# %%
# Export the prediction to a CSV file
p.to_csv('Prediction.csv',index=False)
